# %%
import torch
from torch.utils.data import DataLoader
from pathlib import Path
import matplotlib.pyplot as plt

from vocab import Vocab
from dataset import Paint2CodeDataset
from utils import collate_fn, save_model, img_transformation
from modelCustomCNN import Encoder, Decoder

# %%
# Set parameters
data_path = Path("data", "all_data")
vocab_file_path = Path(data_path.parent, "vocab.txt")
use_cuda = True  
img_size = 224
save_after_epochs = 1
models_dir = Path("./modelsCustomCNN/models")
batch_size = 4
epochs = 100
lr = 0.001
seed = 42

# Seed setup for reproducibility
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# %%
vocab = Vocab(vocab_file_path)
assert len(vocab) > 0, "Vocabulary must be non-empty"

print(vocab)
# Out:
# {
#   "START": 0,
#   "END": 1,
#   "PADDING": 2,
#   "UNKNOWN": 3,
#   ",": 4,
#   "btn-body": 5,
#   "btn-header": 6,
#   "double": 7,
#   "header": 8,
#   "image": 9,
#   "quadruple": 10,
#   "row": 11,
#   "single": 12,
#   "small-title": 13,
#   "text": 14,
#   "{": 15,
#   "}": 16
# }

# %%
# Setup GPU for training
device = torch.device("cuda" if torch.cuda.is_available() and use_cuda else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Define image transformation using the ResNet specs
transform_imgs = img_transformation(img_size)

train_loader = DataLoader(
    Paint2CodeDataset(data_path, "train", vocab, transform=transform_imgs),
    batch_size=batch_size,
    collate_fn=lambda data: collate_fn(data, vocab=vocab),
    pin_memory=True if use_cuda else False,
    drop_last=True
)
print("Data loader for train created successfully.")

test_loader = DataLoader(
    Paint2CodeDataset(data_path,"test", vocab, transform=transform_imgs),
    batch_size=batch_size,
    collate_fn=lambda data: collate_fn(data, vocab=vocab),
    pin_memory=True if use_cuda else False,
    drop_last=True
)
print("Data loader for test  created successfully.")
# Out:
# Data loader for train created successfully.
# Data loader for test  created successfully.

# %%
# Model parameters
embed_size = 64
hidden_size = 256
num_layers = 2

# Initialize the Encoder and Decoder
encoder = Encoder(embed_size).to(device)
decoder = Decoder(embed_size, hidden_size, len(vocab), num_layers).to(device)

print("Models are initialized and moved to the designated device.")
# Out:
# Models are initialized and moved to the designated device.

# %%
# Define loss function and optimizer
criterion = torch.nn.CrossEntropyLoss()
params = list(decoder.parameters()) + list(encoder.parameters())
optimizer = torch.optim.Adam(params, lr=lr)

print("Loss function and optimizer are set.")
# Out:
# Loss function and optimizer are set.

# %%
# Initialize lists to store the average losses per epoch
train_losses = []
test_losses = []

print("Starting training...")
for epoch in range(epochs):
    # Training phase
    encoder.train()  # Set the encoder to training mode
    decoder.train()  # Set the decoder to training mode
    total_train_loss = 0
    num_batches = 0

    for images, captions, lengths in train_loader:
        images = images.to(device)
        captions = captions.to(device)
        targets = torch.nn.utils.rnn.pack_padded_sequence(captions, lengths, batch_first=True)[0]

        # Zero the gradients
        encoder.zero_grad()
        decoder.zero_grad()

        # Forward pass
        features = encoder(images)
        output = decoder(features, captions, lengths)

        # Calculate loss
        loss = criterion(output, targets)
        total_train_loss += loss.item()
        loss.backward()
        optimizer.step()
        num_batches += 1

    avg_train_loss = total_train_loss / num_batches
    train_losses.append(avg_train_loss)  # Append the average training loss

    # Testing phase
    encoder.eval()  # Set the encoder to evaluation mode
    decoder.eval()  # Set the decoder to evaluation mode
    total_test_loss = 0
    num_test_batches = 0

    with torch.no_grad():  # No need to track gradients during testing
        for images, captions, lengths in test_loader:
            images = images.to(device)
            captions = captions.to(device)
            targets = torch.nn.utils.rnn.pack_padded_sequence(captions, lengths, batch_first=True)[0]

            # Forward pass
            features = encoder(images)
            output = decoder(features, captions, lengths)

            # Calculate loss
            loss = criterion(output, targets)
            total_test_loss += loss.item()
            num_test_batches += 1

    avg_test_loss = total_test_loss / num_test_batches
    test_losses.append(avg_test_loss)  # Append the average testing loss

    # Print integrated loss statistics in one line
    print(f'Epoch {epoch}: Training Loss {avg_train_loss:.4f}, Test Loss {avg_test_loss:.4f}')

    #Save model checkpoint
    if epoch != 0 and epoch % save_after_epochs == 0:
        save_model(models_dir, encoder, decoder, optimizer, epoch, avg_test_loss, batch_size, vocab)
        print("Saved model checkpoint at epoch:", epoch)

print("Training completed!")
# Out:
# Starting training...
# Epoch 0: Training Loss 0.3758, Test Loss 0.1187
# Epoch 1: Training Loss 0.1178, Test Loss 0.1038
# Saved model checkpoint at epoch: 1
# Epoch 2: Training Loss 0.1031, Test Loss 0.0945
# Saved model checkpoint at epoch: 2
# Epoch 3: Training Loss 0.0962, Test Loss 0.0906
# Saved model checkpoint at epoch: 3
# Epoch 4: Training Loss 0.0913, Test Loss 0.0819
# Saved model checkpoint at epoch: 4
# Epoch 5: Training Loss 0.0884, Test Loss 0.0818
# Saved model checkpoint at epoch: 5
# Epoch 6: Training Loss 0.0869, Test Loss 0.0786
# Saved model checkpoint at epoch: 6
# Epoch 7: Training Loss 0.0895, Test Loss 0.0784
# Saved model checkpoint at epoch: 7
# Epoch 8: Training Loss 0.0822, Test Loss 0.0754
# Saved model checkpoint at epoch: 8
# Epoch 9: Training Loss 0.0804, Test Loss 0.0713
# Saved model checkpoint at epoch: 9
# Epoch 10: Training Loss 0.0773, Test Loss 0.0623
# Saved model checkpoint at epoch: 10
# Epoch 11: Training Loss 0.0742, Test Loss 0.0606
# Saved model checkpoint at epoch: 11
# Epoch 12: Training Loss 0.0711, Test Loss 0.0618
# Saved model checkpoint at epoch: 12
# Epoch 13: Training Loss 0.0704, Test Loss 0.0596
# Saved model checkpoint at epoch: 13
# Epoch 14: Training Loss 0.0694, Test Loss 0.0589
# Saved model checkpoint at epoch: 14
# Epoch 15: Training Loss 0.0686, Test Loss 0.0577
# Saved model checkpoint at epoch: 15
# Epoch 16: Training Loss 0.0673, Test Loss 0.0568
# Saved model checkpoint at epoch: 16
# Epoch 17: Training Loss 0.0661, Test Loss 0.0543
# Saved model checkpoint at epoch: 17
# Epoch 18: Training Loss 0.0689, Test Loss 0.0561
# Saved model checkpoint at epoch: 18
# Epoch 19: Training Loss 0.0649, Test Loss 0.0545
# Saved model checkpoint at epoch: 19
# Epoch 20: Training Loss 0.0640, Test Loss 0.0536
# Saved model checkpoint at epoch: 20
# Epoch 21: Training Loss 0.0621, Test Loss 0.0520
# Saved model checkpoint at epoch: 21
# Epoch 22: Training Loss 0.0616, Test Loss 0.0510
# Saved model checkpoint at epoch: 22
# Epoch 23: Training Loss 0.0606, Test Loss 0.0509
# Saved model checkpoint at epoch: 23
# Epoch 24: Training Loss 0.0598, Test Loss 0.0517
# Saved model checkpoint at epoch: 24
# Epoch 25: Training Loss 0.0599, Test Loss 0.0517
# Saved model checkpoint at epoch: 25
# Epoch 26: Training Loss 0.0595, Test Loss 0.0505
# Saved model checkpoint at epoch: 26
# Epoch 27: Training Loss 0.0585, Test Loss 0.0485
# Saved model checkpoint at epoch: 27
# Epoch 28: Training Loss 0.0573, Test Loss 0.0478
# Saved model checkpoint at epoch: 28
# Epoch 29: Training Loss 0.0572, Test Loss 0.0472
# Saved model checkpoint at epoch: 29
# Epoch 30: Training Loss 0.0556, Test Loss 0.0469
# Saved model checkpoint at epoch: 30
# Epoch 31: Training Loss 0.0559, Test Loss 0.0461
# Saved model checkpoint at epoch: 31
# Epoch 32: Training Loss 0.0546, Test Loss 0.0437
# Saved model checkpoint at epoch: 32
# Epoch 33: Training Loss 0.0536, Test Loss 0.0442
# Saved model checkpoint at epoch: 33
# Epoch 34: Training Loss 0.0521, Test Loss 0.0420
# Saved model checkpoint at epoch: 34
# Epoch 35: Training Loss 0.0512, Test Loss 0.0409
# Saved model checkpoint at epoch: 35
# Epoch 36: Training Loss 0.0509, Test Loss 0.0415
# Saved model checkpoint at epoch: 36
# Epoch 37: Training Loss 0.0511, Test Loss 0.0413
# Saved model checkpoint at epoch: 37
# Epoch 38: Training Loss 0.0495, Test Loss 0.0396
# Saved model checkpoint at epoch: 38
# Epoch 39: Training Loss 0.0488, Test Loss 0.0390
# Saved model checkpoint at epoch: 39
# Epoch 40: Training Loss 0.0485, Test Loss 0.0374
# Saved model checkpoint at epoch: 40
# Epoch 41: Training Loss 0.0475, Test Loss 0.0388
# Saved model checkpoint at epoch: 41
# Epoch 42: Training Loss 0.0477, Test Loss 0.0379
# Saved model checkpoint at epoch: 42
# Epoch 43: Training Loss 0.0468, Test Loss 0.0401
# Saved model checkpoint at epoch: 43
# Epoch 44: Training Loss 0.0462, Test Loss 0.0396
# Saved model checkpoint at epoch: 44
# Epoch 45: Training Loss 0.0464, Test Loss 0.0388
# Saved model checkpoint at epoch: 45
# Epoch 46: Training Loss 0.0453, Test Loss 0.0365
# Saved model checkpoint at epoch: 46
# Epoch 47: Training Loss 0.0444, Test Loss 0.0380
# Saved model checkpoint at epoch: 47
# Epoch 48: Training Loss 0.0438, Test Loss 0.0371
# Saved model checkpoint at epoch: 48
# Epoch 49: Training Loss 0.0448, Test Loss 0.0366
# Saved model checkpoint at epoch: 49
# Epoch 50: Training Loss 0.0420, Test Loss 0.0351
# Saved model checkpoint at epoch: 50
# Epoch 51: Training Loss 0.0446, Test Loss 0.0350
# Saved model checkpoint at epoch: 51
# Epoch 52: Training Loss 0.0421, Test Loss 0.0347
# Saved model checkpoint at epoch: 52
# Epoch 53: Training Loss 0.0430, Test Loss 0.0347
# Saved model checkpoint at epoch: 53
# Epoch 54: Training Loss 0.0419, Test Loss 0.0339
# Saved model checkpoint at epoch: 54
# Epoch 55: Training Loss 0.0406, Test Loss 0.0356
# Saved model checkpoint at epoch: 55
# Epoch 56: Training Loss 0.0397, Test Loss 0.0379
# Saved model checkpoint at epoch: 56
# Epoch 57: Training Loss 0.0402, Test Loss 0.0340
# Saved model checkpoint at epoch: 57
# Epoch 58: Training Loss 0.0406, Test Loss 0.0340
# Saved model checkpoint at epoch: 58
# Epoch 59: Training Loss 0.0398, Test Loss 0.0332
# Saved model checkpoint at epoch: 59
# Epoch 60: Training Loss 0.0395, Test Loss 0.0323
# Saved model checkpoint at epoch: 60
# Epoch 61: Training Loss 0.0387, Test Loss 0.0323
# Saved model checkpoint at epoch: 61
# Epoch 62: Training Loss 0.0377, Test Loss 0.0330
# Saved model checkpoint at epoch: 62
# Epoch 63: Training Loss 0.0371, Test Loss 0.0321
# Saved model checkpoint at epoch: 63
# Epoch 64: Training Loss 0.0369, Test Loss 0.0324
# Saved model checkpoint at epoch: 64
# Epoch 65: Training Loss 0.0361, Test Loss 0.0325
# Saved model checkpoint at epoch: 65
# Epoch 66: Training Loss 0.0373, Test Loss 0.0321
# Saved model checkpoint at epoch: 66
# Epoch 67: Training Loss 0.0347, Test Loss 0.0321
# Saved model checkpoint at epoch: 67
# Epoch 68: Training Loss 0.0358, Test Loss 0.0318
# Saved model checkpoint at epoch: 68
# Epoch 69: Training Loss 0.0360, Test Loss 0.0310
# Saved model checkpoint at epoch: 69
# Epoch 70: Training Loss 0.0352, Test Loss 0.0322
# Saved model checkpoint at epoch: 70
# Epoch 71: Training Loss 0.0345, Test Loss 0.0303
# Saved model checkpoint at epoch: 71
# Epoch 72: Training Loss 0.0336, Test Loss 0.0292
# Saved model checkpoint at epoch: 72
# Epoch 73: Training Loss 0.0337, Test Loss 0.0290
# Saved model checkpoint at epoch: 73
# Epoch 74: Training Loss 0.0348, Test Loss 0.0284
# Saved model checkpoint at epoch: 74
# Epoch 75: Training Loss 0.0327, Test Loss 0.0286
# Saved model checkpoint at epoch: 75
# Epoch 76: Training Loss 0.0330, Test Loss 0.0283
# Saved model checkpoint at epoch: 76
# Epoch 77: Training Loss 0.0312, Test Loss 0.0286
# Saved model checkpoint at epoch: 77
# Epoch 78: Training Loss 0.0319, Test Loss 0.0277
# Saved model checkpoint at epoch: 78
# Epoch 79: Training Loss 0.0306, Test Loss 0.0291
# Saved model checkpoint at epoch: 79
# Epoch 80: Training Loss 0.0325, Test Loss 0.0279
# Saved model checkpoint at epoch: 80
# Epoch 81: Training Loss 0.0309, Test Loss 0.0262
# Saved model checkpoint at epoch: 81
# Epoch 82: Training Loss 0.0309, Test Loss 0.0264
# Saved model checkpoint at epoch: 82
# Epoch 83: Training Loss 0.0303, Test Loss 0.0291
# Saved model checkpoint at epoch: 83
# Epoch 84: Training Loss 0.0300, Test Loss 0.0304
# Saved model checkpoint at epoch: 84
# Epoch 85: Training Loss 0.0310, Test Loss 0.0268
# Saved model checkpoint at epoch: 85
# Epoch 86: Training Loss 0.0302, Test Loss 0.0276
# Saved model checkpoint at epoch: 86
# Epoch 87: Training Loss 0.0289, Test Loss 0.0271
# Saved model checkpoint at epoch: 87
# Epoch 88: Training Loss 0.0293, Test Loss 0.0270
# Saved model checkpoint at epoch: 88
# Epoch 89: Training Loss 0.0287, Test Loss 0.0267
# Saved model checkpoint at epoch: 89
# Epoch 90: Training Loss 0.0285, Test Loss 0.0265
# Saved model checkpoint at epoch: 90
# Epoch 91: Training Loss 0.0276, Test Loss 0.0265
# Saved model checkpoint at epoch: 91
# Epoch 92: Training Loss 0.0281, Test Loss 0.0273
# Saved model checkpoint at epoch: 92
# Epoch 93: Training Loss 0.0281, Test Loss 0.0284
# Saved model checkpoint at epoch: 93
# Epoch 94: Training Loss 0.0277, Test Loss 0.0264
# Saved model checkpoint at epoch: 94
# Epoch 95: Training Loss 0.0268, Test Loss 0.0279
# Saved model checkpoint at epoch: 95
# Epoch 96: Training Loss 0.0266, Test Loss 0.0277
# Saved model checkpoint at epoch: 96
# Epoch 97: Training Loss 0.0264, Test Loss 0.0261
# Saved model checkpoint at epoch: 97
# Epoch 98: Training Loss 0.0270, Test Loss 0.0252
# Saved model checkpoint at epoch: 98
# Epoch 99: Training Loss 0.0259, Test Loss 0.0259
# Saved model checkpoint at epoch: 99
# Training completed!

# %%
# Plot the training and test losses
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(test_losses, label='Test Loss')
plt.title('Training and Test Losses Across Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Save the final model
save_model(models_dir, encoder, decoder, optimizer, epochs*10, loss.item(), batch_size, vocab)
print("Final model saved.")
# Out:
# Final model saved.
