# %% [markdown]
# # Train model with ResNet18

# %%
import torch
from torch.utils.data import DataLoader
from pathlib import Path
import matplotlib.pyplot as plt

from vocab import Vocab
from dataset import Paint2CodeDataset
from utils import collate_fn, save_model, img_transformation
from modelArchitecture.modelResnet18 import Encoder, Decoder

# %% [markdown]
# ## Set parameters

# %%
data_path = Path("data", "all_data")
vocab_file_path = Path(data_path.parent, "vocab.txt")
use_cuda = True  
img_size = 224
save_after_epochs = 1
models_dir = Path("./modelsResNet18/models")
batch_size = 4
epochs = 150
lr = 0.001
seed = 42

# Seed setup for reproducibility
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# %% [markdown]
# ## Set vocabulary

# %%
vocab = Vocab(vocab_file_path)
assert len(vocab) > 0, "Vocabulary must be non-empty"

print(vocab)
# Out:
# {
#   "START": 0,
#   "END": 1,
#   "PADDING": 2,
#   "UNKNOWN": 3,
#   ",": 4,
#   "btn-body": 5,
#   "btn-header": 6,
#   "double": 7,
#   "header": 8,
#   "image": 9,
#   "quadruple": 10,
#   "row": 11,
#   "single": 12,
#   "small-title": 13,
#   "text": 14,
#   "{": 15,
#   "}": 16
# }

# %% [markdown]
# ## Setup GPU for training

# %%
device = torch.device("cuda" if torch.cuda.is_available() and use_cuda else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## Prepare data

# %%
transform_imgs = img_transformation(img_size)

train_loader = DataLoader(
    Paint2CodeDataset(data_path, "train", vocab, transform=transform_imgs),
    batch_size=batch_size,
    collate_fn=lambda data: collate_fn(data, vocab=vocab),
    pin_memory=True if use_cuda else False,
    drop_last=True
)
print("Data loader for train created successfully.")

val_loader = DataLoader(
    Paint2CodeDataset(data_path,"validation", vocab, transform=transform_imgs),
    batch_size=batch_size,
    collate_fn=lambda data: collate_fn(data, vocab=vocab),
    pin_memory=True if use_cuda else False,
    drop_last=True
)
print("Data loader for val  created successfully.")
# Out:
# Data loader for train created successfully.
# Data loader for val  created successfully.

# %% [markdown]
# ## Set model parameters

# %%
embed_size = 64
hidden_size = 256
num_layers = 2

# Initialize the Encoder and Decoder
encoder = Encoder(embed_size).to(device)
decoder = Decoder(embed_size, hidden_size, len(vocab), num_layers).to(device)

print("Models are initialized and moved to the designated device.")
# Out:
# Models are initialized and moved to the designated device.

# %% [markdown]
# ## Define loss function and optimizer

# %%
criterion = torch.nn.CrossEntropyLoss()
params = list(decoder.parameters()) + list(encoder.parameters()) 
optimizer = torch.optim.Adam(params, lr=lr)

print("Loss function and optimizer are set.")
# Out:
# Loss function and optimizer are set.

# %% [markdown]
# ## Training loop

# %%
# Initialize lists to store the average losses per epoch
train_losses = []
val_losses = []

print("Starting training...")
for epoch in range(epochs):
    # Training phase
    encoder.train()  # Set the encoder to training mode
    decoder.train()  # Set the decoder to training mode
    total_train_loss = 0
    num_batches = 0

    for images, captions, lengths in train_loader:
        images = images.to(device)
        captions = captions.to(device)
        targets = torch.nn.utils.rnn.pack_padded_sequence(captions, lengths, batch_first=True)[0]

        # Zero the gradients
        encoder.zero_grad()
        decoder.zero_grad()

        # Forward pass
        features = encoder(images)
        output = decoder(features, captions, lengths)

        # Calculate loss
        loss = criterion(output, targets)
        total_train_loss += loss.item()
        loss.backward()
        optimizer.step()
        num_batches += 1

    avg_train_loss = total_train_loss / num_batches
    train_losses.append(avg_train_loss)  # Append the average training loss

    # val phase
    encoder.eval()  # Set the encoder to evaluation mode
    decoder.eval()  # Set the decoder to evaluation mode
    total_val_loss = 0
    num_val_batches = 0

    with torch.no_grad():  # No need to track gradients during val
        for images, captions, lengths in val_loader:
            images = images.to(device)
            captions = captions.to(device)
            targets = torch.nn.utils.rnn.pack_padded_sequence(captions, lengths, batch_first=True)[0]

            # Forward pass
            features = encoder(images)
            output = decoder(features, captions, lengths)

            # Calculate loss
            loss = criterion(output, targets)
            total_val_loss += loss.item()
            num_val_batches += 1

    avg_val_loss = total_val_loss / num_val_batches
    val_losses.append(avg_val_loss)  # Append the average val loss

    # Print integrated loss statistics in one line
    print(f'Epoch {epoch}: Training Loss {avg_train_loss:.4f}, val Loss {avg_val_loss:.4f}')

    #Save model checkpoint
    if epoch != 0 and epoch % save_after_epochs == 0:
        save_model(models_dir, encoder, decoder, optimizer, epoch, avg_val_loss, batch_size, vocab)
        print("Saved model checkpoint at epoch:", epoch)

print("Training completed!")
# Out:
# Starting training...
# Epoch 0: Training Loss 0.3801, Test Loss 0.1207
# Epoch 1: Training Loss 0.1155, Test Loss 0.1030
# Saved model checkpoint at epoch: 1
# Epoch 2: Training Loss 0.1049, Test Loss 0.0981
# Saved model checkpoint at epoch: 2
# Epoch 3: Training Loss 0.1015, Test Loss 0.0975
# Saved model checkpoint at epoch: 3
# Epoch 4: Training Loss 0.0995, Test Loss 0.0945
# Saved model checkpoint at epoch: 4
# Epoch 5: Training Loss 0.0967, Test Loss 0.0920
# Saved model checkpoint at epoch: 5
# Epoch 6: Training Loss 0.0976, Test Loss 0.0972
# Saved model checkpoint at epoch: 6
# Epoch 7: Training Loss 0.0933, Test Loss 0.0892
# Saved model checkpoint at epoch: 7
# Epoch 8: Training Loss 0.0923, Test Loss 0.0925
# Saved model checkpoint at epoch: 8
# Epoch 9: Training Loss 0.0905, Test Loss 0.0939
# Saved model checkpoint at epoch: 9
# Epoch 10: Training Loss 0.0887, Test Loss 0.0863
# Saved model checkpoint at epoch: 10
# Epoch 11: Training Loss 0.0863, Test Loss 0.0804
# Saved model checkpoint at epoch: 11
# Epoch 12: Training Loss 0.0835, Test Loss 0.0777
# Saved model checkpoint at epoch: 12
# Epoch 13: Training Loss 0.0819, Test Loss 0.0750
# Saved model checkpoint at epoch: 13
# Epoch 14: Training Loss 0.0838, Test Loss 0.0778
# Saved model checkpoint at epoch: 14
# Epoch 15: Training Loss 0.0808, Test Loss 0.0749
# Saved model checkpoint at epoch: 15
# Epoch 16: Training Loss 0.0788, Test Loss 0.0750
# Saved model checkpoint at epoch: 16
# Epoch 17: Training Loss 0.0789, Test Loss 0.0728
# Saved model checkpoint at epoch: 17
# Epoch 18: Training Loss 0.0769, Test Loss 0.0720
# Saved model checkpoint at epoch: 18
# Epoch 19: Training Loss 0.0763, Test Loss 0.0727
# Saved model checkpoint at epoch: 19
# Epoch 20: Training Loss 0.0768, Test Loss 0.0716
# Saved model checkpoint at epoch: 20
# Epoch 21: Training Loss 0.0774, Test Loss 0.0725
# Saved model checkpoint at epoch: 21
# Epoch 22: Training Loss 0.0765, Test Loss 0.0709
# Saved model checkpoint at epoch: 22
# Epoch 23: Training Loss 0.0757, Test Loss 0.0709
# Saved model checkpoint at epoch: 23
# Epoch 24: Training Loss 0.0770, Test Loss 0.0728
# Saved model checkpoint at epoch: 24
# Epoch 25: Training Loss 0.0754, Test Loss 0.0714
# Saved model checkpoint at epoch: 25
# Epoch 26: Training Loss 0.0748, Test Loss 0.0705
# Saved model checkpoint at epoch: 26
# Epoch 27: Training Loss 0.0739, Test Loss 0.0699
# Saved model checkpoint at epoch: 27
# Epoch 28: Training Loss 0.0736, Test Loss 0.0699
# Saved model checkpoint at epoch: 28
# Epoch 29: Training Loss 0.0737, Test Loss 0.0684
# Saved model checkpoint at epoch: 29
# Epoch 30: Training Loss 0.0726, Test Loss 0.0703
# Saved model checkpoint at epoch: 30
# Epoch 31: Training Loss 0.0720, Test Loss 0.0692
# Saved model checkpoint at epoch: 31
# Epoch 32: Training Loss 0.0758, Test Loss 0.0817
# Saved model checkpoint at epoch: 32
# Epoch 33: Training Loss 0.0728, Test Loss 0.0686
# Saved model checkpoint at epoch: 33
# Epoch 34: Training Loss 0.0716, Test Loss 0.0687
# Saved model checkpoint at epoch: 34
# Epoch 35: Training Loss 0.0713, Test Loss 0.0682
# Saved model checkpoint at epoch: 35
# Epoch 36: Training Loss 0.0705, Test Loss 0.0672
# Saved model checkpoint at epoch: 36
# Epoch 37: Training Loss 0.0724, Test Loss 0.0663
# Saved model checkpoint at epoch: 37
# Epoch 38: Training Loss 0.0720, Test Loss 0.0657
# Saved model checkpoint at epoch: 38
# Epoch 39: Training Loss 0.0693, Test Loss 0.0650
# Saved model checkpoint at epoch: 39
# Epoch 40: Training Loss 0.0691, Test Loss 0.0647
# Saved model checkpoint at epoch: 40
# Epoch 41: Training Loss 0.0680, Test Loss 0.0654
# Saved model checkpoint at epoch: 41
# Epoch 42: Training Loss 0.0670, Test Loss 0.0615
# Saved model checkpoint at epoch: 42
# Epoch 43: Training Loss 0.0712, Test Loss 0.0623
# Saved model checkpoint at epoch: 43
# Epoch 44: Training Loss 0.0665, Test Loss 0.0586
# Saved model checkpoint at epoch: 44
# Epoch 45: Training Loss 0.0643, Test Loss 0.0568
# Saved model checkpoint at epoch: 45
# Epoch 46: Training Loss 0.0633, Test Loss 0.0567
# Saved model checkpoint at epoch: 46
# Epoch 47: Training Loss 0.0625, Test Loss 0.0574
# Saved model checkpoint at epoch: 47
# Epoch 48: Training Loss 0.0617, Test Loss 0.0540
# Saved model checkpoint at epoch: 48
# Epoch 49: Training Loss 0.0610, Test Loss 0.0542
# Saved model checkpoint at epoch: 49
# Epoch 50: Training Loss 0.0614, Test Loss 0.0562
# Saved model checkpoint at epoch: 50
# Epoch 51: Training Loss 0.0626, Test Loss 0.0541
# Saved model checkpoint at epoch: 51
# Epoch 52: Training Loss 0.0592, Test Loss 0.0515
# Saved model checkpoint at epoch: 52
# Epoch 53: Training Loss 0.0580, Test Loss 0.0503
# Saved model checkpoint at epoch: 53
# Epoch 54: Training Loss 0.0564, Test Loss 0.0498
# Saved model checkpoint at epoch: 54
# Epoch 55: Training Loss 0.0555, Test Loss 0.0504
# Saved model checkpoint at epoch: 55
# Epoch 56: Training Loss 0.0553, Test Loss 0.0484
# Saved model checkpoint at epoch: 56
# Epoch 57: Training Loss 0.0559, Test Loss 0.0520
# Saved model checkpoint at epoch: 57
# Epoch 58: Training Loss 0.0546, Test Loss 0.0470
# Saved model checkpoint at epoch: 58
# Epoch 59: Training Loss 0.0552, Test Loss 0.0475
# Saved model checkpoint at epoch: 59
# Epoch 60: Training Loss 0.0546, Test Loss 0.0505
# Saved model checkpoint at epoch: 60
# Epoch 61: Training Loss 0.0532, Test Loss 0.0449
# Saved model checkpoint at epoch: 61
# Epoch 62: Training Loss 0.0525, Test Loss 0.0477
# Saved model checkpoint at epoch: 62
# Epoch 63: Training Loss 0.0525, Test Loss 0.0462
# Saved model checkpoint at epoch: 63
# Epoch 64: Training Loss 0.0516, Test Loss 0.0449
# Saved model checkpoint at epoch: 64
# Epoch 65: Training Loss 0.0501, Test Loss 0.0440
# Saved model checkpoint at epoch: 65
# Epoch 66: Training Loss 0.0513, Test Loss 0.0438
# Saved model checkpoint at epoch: 66
# Epoch 67: Training Loss 0.0492, Test Loss 0.0416
# Saved model checkpoint at epoch: 67
# Epoch 68: Training Loss 0.0500, Test Loss 0.0413
# Saved model checkpoint at epoch: 68
# Epoch 69: Training Loss 0.0495, Test Loss 0.0418
# Saved model checkpoint at epoch: 69
# Epoch 70: Training Loss 0.0473, Test Loss 0.0402
# Saved model checkpoint at epoch: 70
# Epoch 71: Training Loss 0.0480, Test Loss 0.0412
# Saved model checkpoint at epoch: 71
# Epoch 72: Training Loss 0.0472, Test Loss 0.0398
# Saved model checkpoint at epoch: 72
# Epoch 73: Training Loss 0.0453, Test Loss 0.0414
# Saved model checkpoint at epoch: 73
# Epoch 74: Training Loss 0.0477, Test Loss 0.0413
# Saved model checkpoint at epoch: 74
# Epoch 75: Training Loss 0.0465, Test Loss 0.0398
# Saved model checkpoint at epoch: 75
# Epoch 76: Training Loss 0.0449, Test Loss 0.0392
# Saved model checkpoint at epoch: 76
# Epoch 77: Training Loss 0.0433, Test Loss 0.0369
# Saved model checkpoint at epoch: 77
# Epoch 78: Training Loss 0.0446, Test Loss 0.0379
# Saved model checkpoint at epoch: 78
# Epoch 79: Training Loss 0.0430, Test Loss 0.0389
# Saved model checkpoint at epoch: 79
# Epoch 80: Training Loss 0.0438, Test Loss 0.0406
# Saved model checkpoint at epoch: 80
# Epoch 81: Training Loss 0.0424, Test Loss 0.0385
# Saved model checkpoint at epoch: 81
# Epoch 82: Training Loss 0.0427, Test Loss 0.0372
# Saved model checkpoint at epoch: 82
# Epoch 83: Training Loss 0.0430, Test Loss 0.0375
# Saved model checkpoint at epoch: 83
# Epoch 84: Training Loss 0.0419, Test Loss 0.0379
# Saved model checkpoint at epoch: 84
# Epoch 85: Training Loss 0.0406, Test Loss 0.0364
# Saved model checkpoint at epoch: 85
# Epoch 86: Training Loss 0.0398, Test Loss 0.0372
# Saved model checkpoint at epoch: 86
# Epoch 87: Training Loss 0.0402, Test Loss 0.0365
# Saved model checkpoint at epoch: 87
# Epoch 88: Training Loss 0.0407, Test Loss 0.0383
# Saved model checkpoint at epoch: 88
# Epoch 89: Training Loss 0.0402, Test Loss 0.0376
# Saved model checkpoint at epoch: 89
# Epoch 90: Training Loss 0.0393, Test Loss 0.0357
# Saved model checkpoint at epoch: 90
# Epoch 91: Training Loss 0.0392, Test Loss 0.0376
# Saved model checkpoint at epoch: 91
# Epoch 92: Training Loss 0.0381, Test Loss 0.0365
# Saved model checkpoint at epoch: 92
# Epoch 93: Training Loss 0.0389, Test Loss 0.0357
# Saved model checkpoint at epoch: 93
# Epoch 94: Training Loss 0.0376, Test Loss 0.0353
# Saved model checkpoint at epoch: 94
# Epoch 95: Training Loss 0.0368, Test Loss 0.0356
# Saved model checkpoint at epoch: 95
# Epoch 96: Training Loss 0.0373, Test Loss 0.0331
# Saved model checkpoint at epoch: 96
# Epoch 97: Training Loss 0.0368, Test Loss 0.0370
# Saved model checkpoint at epoch: 97
# Epoch 98: Training Loss 0.0362, Test Loss 0.0358
# Saved model checkpoint at epoch: 98
# Epoch 99: Training Loss 0.0349, Test Loss 0.0347
# Saved model checkpoint at epoch: 99
# Epoch 100: Training Loss 0.0354, Test Loss 0.0347
# Saved model checkpoint at epoch: 100
# Epoch 101: Training Loss 0.0343, Test Loss 0.0342
# Saved model checkpoint at epoch: 101
# Epoch 102: Training Loss 0.0347, Test Loss 0.0351
# Saved model checkpoint at epoch: 102
# Epoch 103: Training Loss 0.0365, Test Loss 0.0346
# Saved model checkpoint at epoch: 103
# Epoch 104: Training Loss 0.0356, Test Loss 0.0354
# Saved model checkpoint at epoch: 104
# Epoch 105: Training Loss 0.0330, Test Loss 0.0332
# Saved model checkpoint at epoch: 105
# Epoch 106: Training Loss 0.0334, Test Loss 0.0324
# Saved model checkpoint at epoch: 106
# Epoch 107: Training Loss 0.0331, Test Loss 0.0321
# Saved model checkpoint at epoch: 107
# Epoch 108: Training Loss 0.0338, Test Loss 0.0313
# Saved model checkpoint at epoch: 108
# Epoch 109: Training Loss 0.0321, Test Loss 0.0314
# Saved model checkpoint at epoch: 109
# Epoch 110: Training Loss 0.0324, Test Loss 0.0310
# Saved model checkpoint at epoch: 110
# Epoch 111: Training Loss 0.0319, Test Loss 0.0339
# Saved model checkpoint at epoch: 111
# Epoch 112: Training Loss 0.0308, Test Loss 0.0343
# Saved model checkpoint at epoch: 112
# Epoch 113: Training Loss 0.0302, Test Loss 0.0316
# Saved model checkpoint at epoch: 113
# Epoch 114: Training Loss 0.0329, Test Loss 0.0306
# Saved model checkpoint at epoch: 114
# Epoch 115: Training Loss 0.0318, Test Loss 0.0344
# Saved model checkpoint at epoch: 115
# Epoch 116: Training Loss 0.0305, Test Loss 0.0329
# Saved model checkpoint at epoch: 116
# Epoch 117: Training Loss 0.0303, Test Loss 0.0299
# Saved model checkpoint at epoch: 117
# Epoch 118: Training Loss 0.0291, Test Loss 0.0298
# Saved model checkpoint at epoch: 118
# Epoch 119: Training Loss 0.0310, Test Loss 0.0312
# Saved model checkpoint at epoch: 119
# Epoch 120: Training Loss 0.0284, Test Loss 0.0287
# Saved model checkpoint at epoch: 120
# Epoch 121: Training Loss 0.0288, Test Loss 0.0301
# Saved model checkpoint at epoch: 121
# Epoch 122: Training Loss 0.0288, Test Loss 0.0297
# Saved model checkpoint at epoch: 122
# Epoch 123: Training Loss 0.0285, Test Loss 0.0295
# Saved model checkpoint at epoch: 123
# Epoch 124: Training Loss 0.0273, Test Loss 0.0291
# Saved model checkpoint at epoch: 124
# Epoch 125: Training Loss 0.0281, Test Loss 0.0318
# Saved model checkpoint at epoch: 125
# Epoch 126: Training Loss 0.0292, Test Loss 0.0304
# Saved model checkpoint at epoch: 126
# Epoch 127: Training Loss 0.0275, Test Loss 0.0311
# Saved model checkpoint at epoch: 127
# Epoch 128: Training Loss 0.0270, Test Loss 0.0293
# Saved model checkpoint at epoch: 128
# Epoch 129: Training Loss 0.0275, Test Loss 0.0303
# Saved model checkpoint at epoch: 129
# Epoch 130: Training Loss 0.0268, Test Loss 0.0300
# Saved model checkpoint at epoch: 130
# Epoch 131: Training Loss 0.0259, Test Loss 0.0298
# Saved model checkpoint at epoch: 131
# Epoch 132: Training Loss 0.0260, Test Loss 0.0297
# Saved model checkpoint at epoch: 132
# Epoch 133: Training Loss 0.0256, Test Loss 0.0292
# Saved model checkpoint at epoch: 133
# Epoch 134: Training Loss 0.0256, Test Loss 0.0297
# Saved model checkpoint at epoch: 134
# Epoch 135: Training Loss 0.0260, Test Loss 0.0303
# Saved model checkpoint at epoch: 135
# Epoch 136: Training Loss 0.0247, Test Loss 0.0290
# Saved model checkpoint at epoch: 136
# Epoch 137: Training Loss 0.0236, Test Loss 0.0303
# Saved model checkpoint at epoch: 137
# Epoch 138: Training Loss 0.0250, Test Loss 0.0291
# Saved model checkpoint at epoch: 138
# Epoch 139: Training Loss 0.0237, Test Loss 0.0299
# Saved model checkpoint at epoch: 139
# Epoch 140: Training Loss 0.0238, Test Loss 0.0270
# Saved model checkpoint at epoch: 140
# Epoch 141: Training Loss 0.0239, Test Loss 0.0280
# Saved model checkpoint at epoch: 141
# Epoch 142: Training Loss 0.0250, Test Loss 0.0294
# Saved model checkpoint at epoch: 142
# Epoch 143: Training Loss 0.0239, Test Loss 0.0280
# Saved model checkpoint at epoch: 143
# Epoch 144: Training Loss 0.0237, Test Loss 0.0302
# Saved model checkpoint at epoch: 144
# Epoch 145: Training Loss 0.0232, Test Loss 0.0289
# Saved model checkpoint at epoch: 145
# Epoch 146: Training Loss 0.0235, Test Loss 0.0301
# Saved model checkpoint at epoch: 146
# Epoch 147: Training Loss 0.0225, Test Loss 0.0307
# Saved model checkpoint at epoch: 147
# Epoch 148: Training Loss 0.0225, Test Loss 0.0297
# Saved model checkpoint at epoch: 148
# Epoch 149: Training Loss 0.0216, Test Loss 0.0303
# Saved model checkpoint at epoch: 149
# Training completed!

# %% [markdown]
# ## Plot the training and val losses

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='val Loss')
plt.title('Training and val Losses Across Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
